# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# 1. Explain the key features of Python that make it a popular choice for programming.
#
# Ans. Python is a popular programming language for many reasons, including its simplicity, versatility, Dynamic Memory Allocation and large ecosystem of libraries and frameworks. Some of its features are as follows:
#
# 1. Free to use and distribute
#
# 2. Easy to Learn
#
# 3. Easy to Code
#
# 4. Cross-platform Language
#
# 5. Database Support
#
# 6. Interpreted Language
#
# 7. Object-oriented Language
#
# 8. Huge Community Support
#
# 9. GUI Programming Support
#
# 10. High-level Language
#
# _______________________________________________________
#
#
# 2. Describe the role of predefined keywords in Python and provide examples of how they are used in a
# program.
#
# Ans. Keywords are used to define the syntax of the coding. The keyword cannot be used as an identifier, function, or variable name. All the keywords in Python are written in lowercase except True and False.Python has many predifined functions some of them are as follows:
#
# 1.def: This keyword is like a label for creating functions. Functions are small sections of code that perform specific tasks. In our example, register and login are functions that handle user registration and login.
#
# 2.if and else: These words help the program make decisions. For example, if we want to check if a username is already taken, we use if. If it’s not taken, we use else to tell the program what to do next.
#
# 3.return: This keyword is like a way for functions to send back results. After doing their job, functions can use return to give information back to the part of the program that called them, like saying whether registration or login was successful.
#
# 4.import: This keyword allows us to bring in additional tools or libraries from Python’s collection. It’s not used in our simple example, but it’s very helpful when you need extra features, like encrypting passwords.
#
# 5.__name__ and __main__: These are special names used to check how the script is being run. If you run the script directly, the code inside if __name__ == "__main__": will run. If the script is being imported into another script, that part won’t run. It helps keep things organized.
#
# _______________________________________________________
#
# 3.Compare and contrast mutable and immutable objects in Python with examples.
#
# Ans. There are two types of objects in Python i.e. Mutable and Immutable objects.
#
# 1.Mutable Objects: Mutable Objects are of type Python list, Python dict, or Python set. Custom classes are generally mutable. Aer used when you need to modify, add, or remove existing data frequently.
#
# Example:If we take a Python List object and try to modify its value using the index. A list in Python is mutable, that is, it allows us to change its value once it is created:
#
# my_list = [1, 2, 3]
# my_list.append(4)
# print(my_list)
#
# output= [1, 2, 3, 4]
#
# 2.Immutable Objects: Immutable Objects are of in-built datatypes like int, float, bool, string, Unicode, and tuple. In simple words, an immutable object can’t be changed after it is created. Are used When you want to ensure data remains consistent and unaltered.
#
# Example: iF we take a tuple and try to modify its value at a particular index and print it. As a tuple is an immutable object, it will throw an error when we try to modify it:
#
# tuple1 = (0, 1, 2, 3)
# tuple1[0] = 4
# print(tuple1)
#
# output= TypeError: 'tuple' object does not support item assignment.
#
# _______________________________________________________
#
#
# 4.Discuss the different types of operators in Python and provide examples of how they are used.
#
# Ans. In Python, operators are special symbols or keywords that carry out operations on values and python variables. They serve as a basis for expressions, which are used to modify data and execute computations. Python contains several operators, each with its unique purpose.
#
# 1.Python Arithmetic Operators:
# Mathematical operations including addition, subtraction, multiplication, and division are commonly carried out using Python arithmetic operators.some other operaters are there are operators for modulus, exponentiation, and floor division.
#
# 2.Python Comparison Operators:
# To compare two values, Python comparison operators are needed.Based on the comparison, they produce a Boolean value (True or False). some comparison operaters are: Equal, Not Equal, Greater than, Greater than or equal to, Less than, Less than or equal to.
#
# 3.Python Assignment Operators:
# Python assignment operators are used to assign values to variables in Python.The single equal symbol (=) is the most fundamental assignment operator.It assigns the value on the operator's right side to the variable on the operator's left side.
#
# (=)	Assignment Operator
# (+=)	Addition Assignment
# (-=)	Subtraction Assignment
# (*=)	Multiplication Assignment
# (/=)	Division Assignment
# (%=)	Remainder Assignment
# (**=)	Exponent Assignment
# (//=)	Floor Division Assignment
#
# 4.Python Bitwise Operators
# Python bitwise operators execute operations on individual bits of binary integers.
# They work with integer binary representations, performing logical operations on each bit location.
# Python includes various bitwise operators, such as AND (&), OR (|), NOT (), XOR (), left shift (), and right shift (>>).
#
# 5.Python Logical Operators
# Python logical operators are used to compose Boolean expressions and evaluate their truth values.
# They are required for the creation of conditional statements as well as for managing the flow of execution in programs.
# Python has three basic logical operators: AND, OR, and NOT.
#
# 6.Python Membership Operators
# Python membership operators are used to determine whether or not a certain value occurs within a sequence.
# They make it simple to determine the membership of elements in various Python data structures such as lists, tuples, sets, and strings.
# Python has two primary membership operators: the in and not in operators.
#
# 7.Python Identity Operators
# Python identity operators are used to compare two objects' memory addresses rather than their values.
# If the two objects refer to the same memory address, they evaluate to True; otherwise, they evaluate to False.
# Python includes two identity operators: the is and is not operators.
#
# _______________________________________________________
#
#
# 5.Explain the concept of type casting in Python with examples.
#
# Ans. Type casting in Python is the process of changing a variable's data type to another. There are two types of type casting in Python:
# Implicit
# Automatically converts a variable's data type without the programmer's intervention. This usually happens when converting a smaller data type to a larger one to avoid data loss. For example, when adding an integer to a float, Python automatically converts the integer to a float.
# Python automatically converts
# a to int:
# a = 7
# print(type(a))
#
# output:
# <class 'int'>
#
# Explicit
# Manually converts a variable's data type using built-in functions like int(), float(), or str(). This is used when the programmer needs to change a variable's data type to perform specific operations. For example, to convert a string to an integer, the programmer can use the int() function int variable
#
#  = 5
#
# # typecast to float
# n = float(a)
#
# print(n)
# print(type(n))
#
# output:
# 5.0
# <class 'float'>
#
# ______________________________________________________
#
#
#
# 6. How do conditional statements work in Python? Illustrate with example
#
# Ans. Conditional statements control whether or not certain parts of code are executed based on logical criteria.
#
# If statement: Checks if a number is positive.
# Code:
#
#   num = 5
#   if num > 0:
#       print("The number is positive.")
#
#   Output:
#   The no. is positive.
#
#   Python If-Else Statement
# An if statement can have an optional else clause to form an if-else statement in Python. The else clause of an if-else statement executes the block of code below the else clause only in case the if statement’s condition evaluates to False.
#
# Code:
#
# if condition:
# 	# Execute this code if the condition is True
# else:
# 	# Execute this code if the condition is False
#
# 1.if: The keyword that initiates an if statement.
# 2.condition: A boolean expression that the if statement evaluates. If the expression evaluates to True, the if statement’s body executes. If the expression evaluates to False, the if statement’s body is skipped.
# 3.else: The keyword that initiates an else clause.
#
#   Python If-Elif-Else Statement
# An if statement can have optional elif clauses to form an if-elif statement. Elif clauses can check for additional conditions. As soon as a condition evaluates to True, the block of code below that if or elif clause executes.
#
# Code:
#
# if condition1:
# 	# Execute this code if condition1 is True
# elif condition2:
# 	# Execute this code if condition2 is True
# else:
# 	# Execute this code if condition1 and condition2 are False
#
# elif: The keyword that initiates an elif clause.
# condition2: A boolean expression that the elif clause evaluates if the previous condition evaluated to False. If the expression evaluates to True, the elif clause’s body executes and any following elif and else clauses are skipped. If the expression evaluates to False, the elif clause’s body gets skipped.
#
# ________________________________________________________________________________
#
# 7. Describe the different types of loops in Python and their use cases with examples.
#
# Ans. n Python, we have two main types of loops: for loops and while loops. Each is used for different purposes based on the situation.
#
# 1. for Loop:
# The for loop is used when we know the number of iterations beforehand, or when we want to iterate over a collection of items (like a list, string, tuple, etc.).
#
# Code:
# fruits = ["apple", "banana", "cherry"]
# for fruit in fruits:
#     print(fruit)
# Explanation:
# Here, each item in the fruits list is printed one by one.
#
# 2.while Loop:
# The while loop is used when we want to repeat a block of code as long as a condition is True. It’s useful when the number of iterations isn’t fixed and depends on some condition changing within the loop.
# Example 1: Basic while loop with a counter
#
# Copy:
# count = 1
# while count <= 5:
#     print("Count is:", count)
#     count += 1
# Explanation:
# This loop will print the value of count from 1 to 5. After each print, count increases by 1 until the condition count <= 5 becomes False.
#
# 3.Nested loops: A loop that exists inside the body of another loop.
